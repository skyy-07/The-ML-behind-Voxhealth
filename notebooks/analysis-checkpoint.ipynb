# %% [markdown]
# # Parkinson's Disease Analysis
#
# This notebook analyzes the Parkinson's disease dataset using TensorFlow and Keras.

# %%
# 1. Standard Libraries
import os
import sys

# 2. Data Manipulation
import pandas as pd
import numpy as np

# 3. Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# 4. Machine Learning (Scikit-Learn)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 5. Deep Learning (TensorFlow/Keras)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

# Configure visualization
# %matplotlib inline
sns.set_style('whitegrid')

print(f"TensorFlow Version: {tf.__version__}")

# %%
# Load the dataset
data_path = 'parkinsons.data'

try:
    df = pd.read_csv(data_path)
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print(f"Error: File '{data_path}' not found. Please ensure it is in the same directory.")

# Display the first few rows
df.head()

# %%
# Basic Information
df.info()

# %%
# Check for missing values
df.isnull().sum()
